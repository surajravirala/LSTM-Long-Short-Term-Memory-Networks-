# %% [markdown]
# <a href="https://colab.research.google.com/github/surajravirala/LSTM-Long-Short-Term-Memory-Networks-/blob/main/LSTM_(Long_Short_Term_Memory_Networks).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ** LSTM (Long Short Term Memory Networks)**

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print(f'User uploaded file "{fn}" with length {len(uploaded[fn])} bytes')
# Out:
#      <input type="file" id="files-bdf14ba2-d446-412c-beed-23f913ef59bb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bdf14ba2-d446-412c-beed-23f913ef59bb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset_train=pd.read_csv('Google_Stock_Price_Train.csv')
dataset_train.head()
# Out:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800

# %% [markdown]
# * selecting the Column (or) Row

# %%
training_set=dataset_train.iloc[:,1:2].values
training_set
# Out:
# array([[325.25],
#        [331.27],
#        [329.83],
#        ...,
#        [793.7 ],
#        [783.33],
#        [782.75]])

# %% [markdown]
# * Featuring Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
sc=MinMaxScaler()
training_set_scaled=sc.fit_transform(training_set)
training_set_scaled
# Out:
# array([[0.08581368],
#        [0.09701243],
#        [0.09433366],
#        ...,
#        [0.95725128],
#        [0.93796041],
#        [0.93688146]])

# %%
training_set.shape
# Out:
# (1258, 1)

# %% [markdown]
# * Converting a Data Structure with 60 timesteps(Previous data) and Output

# %%
x_train=[]
y_train=[]
for i in range(60,1258):
  x_train.append(training_set_scaled[i-60:i,0])
  y_train.append(training_set_scaled[i,0])
x_train,y_train=np.array(x_train),np.array(y_train)

# %% [markdown]
# * Reshaping

# %%
x_train=np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))

# %%
x_train.shape[0]
# Out:
# 1198

# %%
x_train.shape[1]
# Out:
# 60

# %% [markdown]
# * Fitting The RNN to the Training Set

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout

# Initialize the RNN
regressor = Sequential()


regressor.add(LSTM(units=50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
regressor.add(Dropout(0.2))


regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Add the Third LSTM layer and some Dropout
# This layer also receives 3D output
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))

# Add the fourth LSTM layer and some Dropout
# This is the last LSTM layer before the Dense output, so return_sequences should be False.
# It is False by default, but explicitly setting it to False for clarity.
regressor.add(LSTM(units=50, return_sequences=False))
regressor.add(Dropout(0.2))

# Output Layer
# This Dense layer expects a 2D input (samples, features), which is what the last LSTM (with return_sequences=False) will provide
regressor.add(Dense(units=1))

# Compiling The RNN
regressor.compile(optimizer='adam', loss='mean_squared_error')

# Fitting The RNN to the Training Set
regressor.fit(x_train, y_train, epochs=50, batch_size=32)

pred = regressor.predict(x_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - loss: 0.1263
# Epoch 2/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 92ms/step - loss: 0.0077
# Epoch 3/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0056
# Epoch 4/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - loss: 0.0059
# Epoch 5/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - loss: 0.0061
# Epoch 6/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 3s 91ms/step - loss: 0.0049
# Epoch 7/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 93ms/step - loss: 0.0048
# Epoch 8/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 96ms/step - loss: 0.0053
# Epoch 9/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 5s 92ms/step - loss: 0.0050
# Epoch 10/50
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 0.0040
# ...

# %%
import math
from sklearn.metrics import mean_squared_error
rmse=math.sqrt(mean_squared_error(y_train,pred))
rmse
# Out:
# 0.030910737315318838
